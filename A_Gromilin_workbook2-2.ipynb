# %% [markdown]
# 1)Дано: X10 = 1010102. Найти X10.
#
# 0*0+1*2^1+0*2^2+1*2^3+0*2^4+1*2^5=42(10)

# %% [markdown]
# 2)
# Дано: X10 = 5638. Найти X10.
#
# 5 * 8^2 + 6 * 8 + 3 * 1 = 320 + 48 + 3 = 371(10)

# %% [markdown]
# 3) Дано: X10 = A1286(12). Найти X10.
#
# 10*12^4+1*12^3+2*12^2+8*12^1+6=209478(10)

# %% [markdown]
# 4) Сколько единиц в двоичной записи числа 127?
#
# Ответ: 7

# %%
a=127
a=bin(a)
print(a.count("1"))
# Out:
# 7

# %% [markdown]
# 5) Дано: 367(10) = X7. Найти X.
#
# 367/7=52;3
# 52/7=7;3
# 7/7=1;0
# 1/7=0;1
#
# Ответ: 1033

# %% [markdown]
# 6) Дано: 1143(10) = X(12). Найти X.
#
# 1143/12=95;3
# 95/12=7;11=B
# 7/12=0;7
#
# Ответ: 7B3

# %% [markdown]
# 7) Дано: 127(8) = X(9). Найти X.
#
# 1 * 8^2 + 2 * 8^1 + 7 = 87(10)
#
# 87/9=9;6
# 9/9=1;0
# 1/9=0;1
#
# Ответ: 106

# %% [markdown]
# 8) Дано: AB4(13) = X(6). Найти X.
#
# 10 * 13^2 + 11 * 13^1 + 4 × 1 = 1837(10)
#
# 1837/6=306;1
# 306/6=51;0
# 51/6=8;3
# 8/6=1;2
# 1/6=0;1
#
# 12301(6)

# %% [markdown]
# 9) Дано: 1010011101(2) = X(16). Найти X.
#
# 2^9 + 0 + 1 * 2^7 + 0 + 0 + 1 * 2^4 + 1 * 2^3 + 1 * 2^2 + 0 + 1 * 2^0 = 669(10)
#
# 669/16=41;13=D
# 41/2;9
# 2/16=0;2
#
# Ответ: 29D

# %% [markdown]
# 10) Дано: 1147453(8) = X(2). Найти X.
#
# 1 * 8^6 + 1 * 8^5 + 4 * 8^4 + 7 * 8^3 + 4 * 8^2 + 5 * 8^1 + 3 * 8^0 = 315179(10)
# ![Снимок экрана 2024-09-19 в 10.06.49.png](data:image/png;base64,...)
#
# Ответ: 1001100111100101011

# %% [markdown]
# 11) Дано: 1278 = X16. Найти X.
#
# 1 * 8^2 + 2 * 8^1 + 7 * 8^0 = 87(10)
#
# 87/16=5;7
# 5/16=0;5
#
# Ответ: 57

# %% [markdown]
# Сколько значащих нулей в двоичной записи шестнадцатеричного числа
# C3E116?
#
# C = 1100
# 3 = 0011
# E = 1110
# 1 = 0001 ![Снимок экрана 2024-09-19 в 10.10.41.png](data:image/png;base64,...)
#
# Ответ: 5

# %% [markdown]
# 12) Дано: AF38(32) = X(16) = X(8) = X(2).
#
# A = 10
# F = 15
#
# 10 * 16^3 + 15 * 16^2 + 3 * 16^1 + 8 * 16^0 = 44856(16)
#
# 44856(16) = 4 * 16^3 + 4 * 16^2 + 8 * 16^1+5 * 16^0 = 5253(10)
#
# 5253(10) / 8 =656;5
# 656 / 8 = 82;0
# 82 / 8 = 10;2
# 10 / 8 = 1;2
# 1 / 8 = 0;1
#
# 12205(8)
#
# 1 = 001
# 2 = 010
# 2 = 010
# 0 = 000
# 5 = 101
#
# 001 010 010 000 101(2)
#
# Ответ: AF38(32)=44856(16)=12205(8)=1010010000101(2)

# %% [markdown]
# 13) Некоторое число X из десятичной системы счисления перевели в
# системы счисления с основаниями 16, 8, 4, 2. Часть символов при записи
# утеряна. Позиции утерянных символов обозначены знаком *
# X = E * 16 = * 5 * 8 = * * * 14 = * * * * * 1 * * 2
# Определите число X.
#
# X = 14*161 + a*1 = 224 + a
#
# a=13(D)
#
# X = 14*161 + D*1 = 224 + 13 =237
#
# 237 = ED16 = 23716 = 3558 = 32314 = 111011012
#
# Ответ:
# X = 237

# %% [markdown]
# # Тест 2

# %% [markdown]
# 1) Переведите число 37 из десятичной системы счисления в двоичную:
#
# А) 100101;
#
# 2) Переведите число 110102 из двоичной системы счисления в десятичную
# систему счисления.
#
# С) 26;
#
# 3) Дано: а = D716, b = 3318. Какое из чисел с, записанных в двоичной
# системе, отвечают условию a<c<b?
#
# D) 11011000
#
# 4) Для чисел, заданных в различных системах счисления: X = 11123, Y
# = 1405, Z = 2224 – справедливо соотношение:
#
# B) X<Z<Y
#
# 5) В системе счисления с некоторым основанием десятичное число 144
# записывается в виде 264. Укажите это основание.
#
# C) 7
#
# 6) Укажите основание системы счисления, которой не может быть
# записано число 1302
#
# A) 3
#
# 7) Значение выражения 1016 + 108 * 102 в двоичной системе счисления
# равно
#
# B) 11010
#
# 8) Укажите через запятую в порядке возрастания все основания систем
# счисления, в которых запись числа 40 оканчивается на 4.
#
# Ответ: 4, 8, 16
#
# 9) В системе счисления с некоторым основанием десятичное число 52
# записывается в виде 202n. Найдите n .
#
# Ответ: 10
#
# 10) Решите уравнение: 126 + x = 3245 Ответ запишите в десятичной системе
# счисления.
# Ответ: 1548

# %% [markdown]
# # Python

# %% [markdown]
# 1) На вход программа получает две величины: n, A, где n – натуральное числа от 2 до 36, основание системы счисления, A – число, записанное в системе счисления с основанием n, A < 231.
# Необходимо вывести значение A в системе счисления с основанием десять. В задаче подразумевается корректный ввод (т.е. в числе A отсутствуют цифры большие или равные n).

# %%
def convert(n, A):
    decimal = 0
    digits = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    for i, digit in enumerate(reversed(A)):
        decimal = decimal * n + digits.index(digit)
    return decimal
n = int(input("введите основание системы счисления (от 2 до 36): "))
A = input("введите число A: ")
decimal_A = convert(n, A)
print(f"число {A} в системе счисления с основанием {n} равно {decimal_A} в десятичной системе.")

# %% [markdown]
# 2) Дано двузначное число. Определить входит ли в него цифра 3. (// - операция получения целой части от деления, % - операция взятия остатка от целочисленного деления).

# %%
def contains_digit_3(number):
    tens = number // 10
    ones = number % 10
    return 3 in [tens, ones]
number = int(input("введите двузначное число: "))

if contains_digit_3(number):
    print(f"число {number} содержит цифру 3.")
else:
    print(f"число {number} не содержит цифры 3.")

# %% [markdown]
# 3)  Дано двузначное число. Определить какая из его цифр больше

# %%
number1 = int(input("введите двузначное число: "))
tens1 = number1 // 10
ones1 = number1 % 10
if tens1>ones1:
    print(f"Наибольшая цифра: {tens1}")
else:
    print(f"Наибольшая цифра: {ones1}")

# %% [markdown]
# 4) Найти корни квадратного уравнения и вывести их на экран, если они есть. Если корней нет, то вывести сообщение об этом. Конкретное квадратное уравнение определяется коэффициентами a, b, c, которые вводит пользователь.

# %%
import math
a = float(input("введите a (a ≠ 0): "))
b = float(input("введите b: "))
c = float(input("введите c: "))
D = b**2 - 4*a*c
if D > 0:
    x1 = (-b + math.sqrt(D)) / (2 * a)
    x2 = (-b - math.sqrt(D)) / (2 * a)
    print(f"два корня: x1 = {x1}, x2 = {x2}")
elif D == 0:
    x = -b / (2 * a)
    print(f"один корень: x = {x}")
else:
    print("нет корней.")

# %% [markdown]
# 5) Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.

# %%
p=int(input("введите ваше число для нахождения наименьшего делителя:"))
h=[]
for y in range (1,10):
    if p%y==0:
        y=str(y)
        h.append(y)
print(f"наименьший целый делитель для числа {p} это: {h[1]}")

# %% [markdown]
# 6) Посчитать сумму числового ряда от 1 до N включительно (т.е. 0+1+2+3+…+ N). Решите задачу с помощью и без помощи оператора цикла. Число N вводится с клавиатуры (N< 1000).

# %%
N = int(input("введите число N (N < 1000): "))
if N >= 1000:
    print("число N должно быть меньше 1000.")
else:
    total_sum = N * (N + 1) // 2
    print(f"сумма чисел от 1 до {N} равна {total_sum}.")

# %% [markdown]
# 7) Простыми являются натуральные числа больше 1, которые делятся нацело только на 1 и самих себя. На вход программе подается число. Необходимо проверить является ли оно простым.

# %%
num = int(input("введите натуральное число больше 1: "))
def prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True
print(f"{num} {'является' if prime(num) else 'не является'} простым числом.")

# %% [markdown]
# 8) Вводится десятичное число A (A< 2^31) и число n (2 ≤ n ≤ 9). Необходимо перевести введенное число A в систему счисления c основанием n. При этом использовать встроенные конструкции языка Python не разрешается.

# %%
a4 = int(input("введите число a (a < 2^31): "))
n4 = int(input("введите основание n (2 ≤ n ≤ 9): "))
if 2 <= n4 <= 9:
    result1 = ""
    while a4 > 0:
        result1 = str(a4 % n4) + result1
        a4 //= n4
    print(f"ваше число в системе счисления с основанием {n4}: {result1}")
else:
    print("основание n должно быть от 2 до 9.")
