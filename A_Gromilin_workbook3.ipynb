# %% [markdown]
# # 1 часть

# %% [markdown]
# 1) Найти представление беззнакового числа 132(10) в шестнадцатиразрядном
# битовом наборе
#
# 132 / 2 = 66 ; 0
#
# 66 / 2 = 33 ; 0
#
# 33 / 2 = 16 ; 1
#
# 16 / 2 = 8 ; 0
#
# 8 / 2 = 4 ; 0
#
# 4 / 2 = 2 ; 0
#
# 2 / 2 = 1 ; 0
#
# 1 / 2 = 0 ; 1
#
# 132(10) = 10000100(2)
#
# 0000000000100000100

# %% [markdown]
# 2) Найти минимальное и максимальное значения чисел для 16-ти
# разрядного беззнакового представления
#
# 1 * 2^0 + 1 * 2^1 + 1 * 2^2 + 1 * 2^3 + 1 * 2^4 + 1 + 1 * 2^5 + 1 * 2^6 + 1 * 2^7 + 1 * 2^8 + 1 * 2^9 + 1 * 2^10 + 1 * 2^11 + 1 * 2^12 + 1 * 2^13 + 1 * 2^14 + 1 * 2^15 = 65535(макс);
#
# 0000000000000000(мин) 0

# %% [markdown]
# 3) Перевести число 12 в прямой, обратный и дополнительный код (k = 8)
#   - 12(10) =      0,00001100(2) (прямой)
#   - 00001100(2) = 0,11110011(2) (обратный) --
#   - 11110011(2) = 0,11110100(2) (дополнительный) --
#
#
#     .
#
#
#   - 00001100(2) = 0,00001100(2) (обратный)
#   - 00001100(2) = 0,00001100(2) (дополнительный)

# %% [markdown]
# 4) Найти прямой, обратный и дополнительный коды в однобайтовом
# представлении для числа -35(10).
#   - -35(10) = 1,10100011(2) (прямой)
#   - 10100011(2) = 1,01011100(2) (обратный)
#   - 01011100(2) = 1,01011101(2) (дополнительный)

# %% [markdown]
# 5) Задан дополнительный код числа в однобайтовом представлении:
# 1,1011100. Найти число в десятичной системе счисления.
#   - 1011100(2)=10100100(2) (обратный)
#   - 10100100(2) = 10100101(2) (дополнительный)
#   - 1 * 2^7 + 0 * 2^6 + 1 * 2^5 + 0 * 2^4 + 0 * 2^3 + 1 * 2^2 + 0 * 2^1 + 1 * 2^0 = -123(10) --
#
# .
#
#   - 1,1011100(2)=0,0100011(2) (обратный)
#   - 1 * 2 ^ 0 + 1 * 2 ^ 1 + 0 * 2 ^ 2 + 0 * 2 ^ 3 + 0 * 2 ^ 4 + 1 * 2 ^ 5 + 0 * 2 ^ 6 = 35(10)

# %% [markdown]
# 6) Дано два десятичных двузначных целых числа: А = 78, В = 56.
# Вычислить (А-В)ок, (В-А)дк.
#   - (А - В) = 78 - 56 = 22(10) = 00010110(2) = 11101001(2) (обратный)
#   - (В - А) = 56 - 78 = -22(10) = 11101110(2) = 00010001(2) (обратный) = 00010010(2) (дополнительный)
# --
#
#   - 78 / 2 = 39; 0
#     2

# %% [markdown]
# # Тест 3

# %% [markdown]
# # 1. Для представления целого числа может применяться
#
#     B) прямой, обратный или дополнительный код.
# # 2. Положительное число:
#
#     C) выглядит одинаково в прямом, обратном и дополнительном кодах.
# # 3. Если взять отрицательное число и инвертировать разряды кроме знакового, то получится
#
#     B) прямой код. --
#
# ---
#     A) обратный код.
#
#
#
#
#
# # 4. Дополнительный код числа получается
#
#     B) из обратного кода прибавлением единицы к младшему разряду с переносом в знаковый разряд. --
#
# ---
#
#
#     A) из обратного кода прибавлением единицы к младшему разряду без переноса в знаковый разряд.
#
# # 5. Если к двоичному числу без знака добавить знаковый разряд то получится
#
#     B) прямой код.
#
#
# # 6. Число Х = 14(10) в восьми разрядном двоичном дополнительном коде равняется
#
#     B) 0110010 --
#
# ---
#
#     A) 00001110
#
#
# # 7. Восьми разрядное двоичное число Х = 10001010(2), заданное в дополнительном коде в десятичной системе равняется
#
#     B) +10 --
#
# ---
#
#     D) –118
#
#
# # 8. Восьми разрядное двоичное число Х = 00100111(2) заданное в обратном коде в десятичной системе равняется
#
#     B) +39
#
# # 9. Число Х = -63(10) в прямом коде будет представлено как
#
#     B) 00111111 --
#
# ---
#
#     A) 10111111
#
# # 10. Укажите дополнительный код десятичного числа -103 (минус сто три) в 8 разрядном компьютерном представлении.
#
#     Ответ: 10000001 --
#
# ---
#
#     Ответ: 10011001

# %% [markdown]
# # Python

# %% [markdown]
# # 1.
# ![Снимок экрана 2024-09-19 в 14.17.48.png](data:image/png;base64,...)

# %%
import math

x = float(input('Введите x '))
y = float(input('Введите y '))
f = math.log(math.sin(x + y))
print('f = ', f)

# %% [markdown]
# # 2.
# ![Снимок экрана 2024-09-19 в 14.19.19.png](data:image/png;base64,...)

# %%
import math
x = float(input('Введите x '))
y = float(input('Введите y '))

if math.sin(x+y)<=-0.5:
    f=math.atan((pow(x-y)**1/3) * (x*math.e**y))
elif -0.5<math.sin(x+y)<0.5:
    f=3*math.log(pow(x*y),[3])
elif math.sin(x+y)>=0.5:
    f=x**3+y**1.5
print("f = ", f)

# %% [markdown]
# # 3. Вычислить значение функции f(x) = cos^3(e*x) + sin|x| на отрезке [a, b] с шагом hx

# %%
import math
def f(x):
    return math.cos(3 * math.exp(x)) + math.sin(abs(x))

a = float(input("Введите начало отрезка a: "))
b = float(input("Введите конец отрезка b: "))
hx = float(input("Введите шаг hx: "))

x = a
while x <= b:
    print(f"f({x:.2f}) = {f(x):.2f}")
    x += hx

# %% [markdown]
# # 4.
# ![Снимок экрана 2024-09-19 в 14.22.47.png](data:image/png;base64,...)

# %%
def f(x, y):
    if x + y <= 2:
        return (math.sin(x * math.exp(0.1 * y)))**(1/3)
    elif x + y > 2:
        return math.pow(math.log2(x + y), 2)
ax = 1
bx = 2.5
ay = 1
by = 4
x = ax
while x <= bx:
    y = ay
    while y <= by:
        print(f"f({x:.2f}, {y:.2f}) = {f(x, y):.2f}")
        y += 1
        x += 0.5
