# %% [markdown]
# # Тест 5
#
#   1. Формула А называется тождественно-ложной если…
#
#           4) для любых наборов переменных она принимает значение Ложь.
#
#   2. Формула А* называется двойственной формуле А, если…
#
#           1) она получена из А одновременной заменой всех символов конъюнкции и дизъюнкции на двойственные
#
#   3. Какая из данных логических функций является тождественно ложной?
#
#           4) 𝐴̅→(𝐴∧𝐵)
#   4. Максимально упростите логическое выражение 𝑌̅∨ (not((𝑋 ∨ 𝑌) ∧ 𝑌̅̅)∧ 𝑋 ∧ 𝑌̅)
#
#           3) 𝑋
#   5. Дана логическая функция. Выберете эквивалентную ей функцию.
# 𝐹(𝑋1, 𝑋2) = (𝑋1 ∧ 𝑋2) ∨ (𝑋1 ∧ not(𝑋2)) ∨ (not(X1) ∧ X2)
#
#           1) 𝑋1 ∨ 𝑋2
#   6. Дана логическая функция. Выберете эквивалентную ей функцию.
# 𝐹(2) = 𝑎 ∧ 𝑏̅ ∨ 𝑐 ∨ 𝑎̅ ∧ 𝑐
#
#           3) (𝑎 ∨ 𝑐) ∧ (𝑎̅ ∨ 𝑏̅ ∨ 𝑐) ∧ (𝑏̅ ∨ 𝑐)
#   7. Сколько слагаемых содержит СДНФ, построенная по функции 𝑓(𝑥1, 𝑥2, 𝑥3)
# заданной так, что на всех наборах значений переменных 𝑥1, 𝑥2, 𝑥3 она
# принимает значение 1?
#
#           4) 8
#
#   8. Сколько сомножителей содержит СКНФ, построенная для функции
# 𝑓(𝑥1, 𝑥2, 𝑥3), для которой 𝑓(1,1,1) = 𝑓(1,0,1) = 0 ? В остальных случаях
# 𝑓(𝑥1, 𝑥2, 𝑥3) = 1.
#
#           2) 2
#
#   9. Найдите СДНФ по таблице истинности
#
#
#   ![Снимок экрана 2024-09-26 в 13.23.27.png](data:image/png;base64,...)
#
#                 2) (𝑋1̅̅̅∧𝑋2̅̅̅)∨(𝑋1̅̅̅∧𝑋2)∨(𝑋1 ∧𝑋2)
#
#   10. Найдите СКНФ по таблице истинности
#
#   ![Снимок экрана 2024-09-26 в 13.26.00.png](data:image/png;base64,...)
#
#                 4) (𝑋1 ∨ not(𝑋2)) ∧ (not(𝑋1) ∨ 𝑋2) ∧ (not(𝑋1) ∨ 𝑋2)

# %% [markdown]
# # Python

# %% [markdown]
# 1. Дано целое число. Требуется определить, является ли данное число
# трехзначным положительным числом, кратным пяти.

# %%
a = int(input("Введите ваше число: "))
if (a%5==0) and (100<=a<=999):
  print(f"Число {a} соответствует всем условиям")
else:
  print(f"Число {a} не соответствует условиям")
# Out:
# Число 308 не соответствует условиям

# %% [markdown]
# 2. Даны 3 целых числа. Требуется определить, есть ли среди этих чисел
# хотя бы два четных.

# %%
def main(a, b, c):
    d = sum(1 for e in (a, b, c) if e % 2 == 0)
    return d >= 2

a = int(input("Введите первое целое число: "))
b = int(input("Введите второе целое число: "))
c = int(input("Введите третье целое число: "))

if main(a, b, c):
    print("Среди введенных чисел есть хотя бы два четных.")
else:
    print("Среди введенных чисел нет хотя бы двух четных.")
# Out:
# Среди введенных чисел есть хотя бы два четных.

# %% [markdown]
# 3.
#
#
# ![Снимок экрана 2024-09-26 в 15.41.00.png](data:image/png;base64,...)

# %%
x = float(input("Введите значение x"))
y = float(input("Введите значение y"))
if x >= 0 and y <= x + 1:
   print(f"Точка ({x};{y}) входит в заштрихованную область")
else:
   print(f"Точка ({x};{y}) не входит в заштрихованную область")
# Out:
# Точка (2.0;1.0) входит в заштрихованную область

# %%
#тернарный оператор
x = float(input("Введите значение x"))
y = float(input("Введите значение y"))

print("Входит" if (x >= 0 and y <= x + 1) else "Не входит")
# Out:
# Входит

# %% [markdown]
# 4.
#
#
# ![Снимок экрана 2024-09-26 в 21.35.43.png](data:image/png;base64,...)

# %%
import math
x = float(input("Введите значение x"))
y = float(input("Введите значение y"))
if y <= 0.5 and y >= 0 and x >= 0 and y <= math.sin(x):        
    print(f"Точка ({x};{y}) входит в заштрихованную область")
else:
    print(f"Точка ({x};{y}) не входит в заштрихованную область")
# Out:
# Точка (0.0;0.0) входит в заштрихованную область

# %%
#тернарный оператор
import math
x = float(input("Введите значение x"))
y = float(input("Введите значение y"))

print("Входит" if (y <= 0.5 and y >= 0 and x >= 0 and y <= math.sin(x)) else "Не входит")

# %% [markdown]
# 5.
#
#
#
# ![Снимок экрана 2024-10-02 в 13.45.28.png](data:image/png;base64,...)

# %%
x = float(input("Введите координату x: "))
y = float(input("Введите координату y: "))

if (y == 0 and x == 0) or y >= x or (y < x and x<=0) and(x<=1 and y<=1):
    print(f"Точка ({x};{y}) находится в заштрихованной области")
else:
    print(f"Точка ({x};{y}) находится вне заштрихованной области")
# Out:
# Точка (1.0;0.0) находится вне заштрихованной области

# %%
#тернарный оператор
x = float(input("Введите координату x: "))
y = float(input("Введите координату y: "))

print("Входит" if ((y == 0 and x == 0) or y >= x or (y < x and x<=0) and(x<=1 and y<=1)) else "Не входит")
# Out:
# Входит
