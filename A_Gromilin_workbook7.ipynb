# %% [markdown]
# # Тест 7

# %% [markdown]
# 1. Алгоритм это:
#
#         б) пошаговое описание последовательности действий, которые необходимо, выполнить для решения задачи
#
# 2. Свойство алгоритма, которое обеспечивает решение целого класса задач
# одного типа:
#
#         г) массовость.
#
# 3. Как называется конструкция блок-схемы, изображенная на рисунке?
#
#         а) вызов вспомогательного алгоритма
#
# 4. На рисунке представлена часть блок-схемы. Как она называется?
#
#         а) альтернатива.
#
# 5. Определите значения переменной «x» после выполнения фрагмента
# алгоритма.
#
#         Ответ: 6
#
# 6. Определите значение переменной «b» после выполнения фрагмента
# алгоритма.
#
#         Ответ: 3
#
# 7. В машине Тьюринга предписание S для лентопротяжного механизма
# означает
#
#         а) переместить ленту вправо;
#
# 8. Конечный автомат – это автомат с ….
#
#         б) конечным числом состояний
#
# 9. Пусть дана машина Тьюринга с внешним алфавитом ∑ = {a,b, _} и
# состояниями Q = {q0, q1, q2}. Программа приведена в таблице:
# В какое слово программа преобразует слово abb, если головка находится
# над первой буквой?
#
#         б) abbb
#
# 10. Машина Тьюринга задана программой, записанной в виде таблицы:
# Определите, в какое слово машина Тьюринга преобразует слово «111», если головка находится над первой (слева направо) единицей?
#
#         а) 111

# %% [markdown]
# # Phyton

# %% [markdown]
# 1. Напишите функцию, которая на вход принимает два целых числа
# (делимое и делитель) и возвращает целую часть от деления и остаток.

# %%
x=int(input("Введите делимое"))
y=int(input("Введите делитель"))
def f(x,y):
    return(x // y,x % y)
print(f"Целая часть и остаток от деления: {f(x,y)}")
# Out:
# Целая часть и остаток от деления: (5, 0)

# %% [markdown]
# 2.Описать функцию Sign(X) целого типа, возвращающую для
# вещественного числа X следующие значения: −1, если X < 0; 0, если X =
# 0; 1, если X > 0.

# %%
x=int(input("Введите число"))
def Sign(x):
    if x < 0:
        return -1
    if x == 0:
        return 0
    if x >0:
        return 1
print(f"Число {x} после функции Sign(x) равно: {Sign(x)}")
# Out:
# Число 7 после функции Sign(x) равно: 1

# %% [markdown]
# 3. Напишите проверку на то, является ли строка палиндромом. Палиндром
# — это слово или фраза, которые одинаково читаются слева направо и
# справа налево.

# %%
a = str(input("Введите вашу строку: "))
def f(a):
    for i in range(len(a)):
        if a[:i] + a[i+1:] == (a[:i] + a[i+1:])[::-1]:
            return 1
    return 0
if f(a) == 1:
    print(f"Строка '{a}' является палиндромом")
else:
    print(f"Строка '{a}' не является палиндромом")
# Out:
# Строка 'radar' является палиндромом

# %% [markdown]
# 4. Сделайте так, чтобы число секунд отображалось в
# видедни:часы:минуты:секунды.

# %%
s = int(input("Введите кол-во секунд: "))

def time(s):
    d = s // 86400
    s %= 86400
    h = s // 3600
    s %= 3600
    m = s // 60
    s %= 60
    
    print(f"{d} - д: {h} - ч: {m} - м: {s} - с")

time(s)
# Out:
# 37 - д: 12 - ч: 59 - м: 3 - с

# %% [markdown]
# 5. Напишите функцию, которая вычисляет любое число Фибоначчи 𝑭𝒏с
# помощью рекурсии.

# %%
import sys
sys.setrecursionlimit(10000)
def f(n):
    if n == 0:
        return 0
    if n == 1:
        return 1
    else:
        return f(n-2)+f(n-1)
n = int(input("Введите ваше n"))
print(f"Ваше число Фибоначчи: {f(n)}, при n равном {n}")
# Out:
# Ваше число Фибоначчи: 55, при n равном 10
